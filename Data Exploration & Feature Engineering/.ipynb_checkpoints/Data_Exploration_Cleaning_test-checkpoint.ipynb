# %%
import boto3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime

# %%
# Defining s3 bucket
s3 = boto3.resource('s3')
bucket_name = 'gabriel-analytics-capstone-bucket'
bucket = s3.Bucket(bucket_name)

# Defining the file to be read from s3 bucket
key_file_test = 'orders_class.txt'


# Test dataset
bucket_object_test = bucket.Object(key_file_test)
file_object_test = bucket_object_test.get()
file_content_stream_test = file_object_test.get('Body')
test = pd.read_csv(file_content_stream_test, sep=";", na_values = '?')

# (b)
test.shape
# Out:
# (50078, 13)

# %%
test.head()
# Out:
#    orderItemID   orderDate deliveryDate  itemID size    color  manufacturerID  \
# 0            1  2013-04-01   2013-04-03    2347   43  magenta               1
# 1            2  2013-04-01   2013-04-03    2741   43     grey               1
# 2            3  2013-04-01   2013-04-03    2514    9     ecru              19
# 3            4  2013-04-01   2013-05-06    2347   42    brown               1
# 4            5  2013-04-01          NaN    2690   43     grey               1
#
#    price  customerID salutation dateOfBirth  state creationDate
# 0   89.9       12489        Mrs  1963-04-26  Hesse   2012-04-23
# 1   99.9       12489        Mrs  1963-04-26  Hesse   2012-04-23
# 2   79.9       12489        Mrs  1963-04-26  Hesse   2012-04-23
# 3   89.9       12489        Mrs  1963-04-26  Hesse   2012-04-23
# 4  119.9       12489        Mrs  1963-04-26  Hesse   2012-04-23

# %% [markdown]
# #### In the intructions of the project, it is stated that "?" is Null Values. Let's double check there is none "?" after specifying na_values = '?' when reading the daset)

# %% [markdown]
# ## Initial Exploration

# %%
## Checking Coefficient = 0 in the columns
for i in range(0, len(test.iloc[0,:])):
    
    count = 0

    for j in range(0, len(test.iloc[:,0])):
    
        if (test.iloc[j, i] == '?'):
            count = count + 1
            
    print("Column Index: ", i)
    print("Number of ? in the column: ", count)
    print('')
# Out:
# Column Index:  0
# Number of ? in the column:  0
#
# Column Index:  1
# Number of ? in the column:  0
#
# Column Index:  2
# Number of ? in the column:  0
#
# Column Index:  3
# Number of ? in the column:  0
#
# Column Index:  4
# Number of ? in the column:  0
#
# Column Index:  5
# Number of ? in the column:  0
#
# Column Index:  6
# Number of ? in the column:  0
#
# Column Index:  7
# Number of ? in the column:  0
#
# Column Index:  8
# Number of ? in the column:  0
#
# Column Index:  9
# Number of ? in the column:  0
#
# Column Index:  10
# Number of ? in the column:  0
#
# Column Index:  11
# Number of ? in the column:  0
#
# Column Index:  12
# Number of ? in the column:  0

# %% [markdown]
# #### orderItemID

# %% [markdown]
# #### orderItemID

# %%
print('There are', len(np.unique(test['orderItemID'])), end=' ')
print("different orders.")
# Out:
# There are 50078 different orders.

# %% [markdown]
# #### manufacturerID

# %%
print('There are', len(np.unique(test['manufacturerID'])), end=' ')
print("different manufacturers.")
# Out:
# There are 119 different manufacturers.

# %% [markdown]
# #### ItemID

# %%
print('There are', len(np.unique(test['itemID'])), end=' ')
print("different items.")
# Out:
# There are 1283 different items.

# %% [markdown]
# #### orderDate

# %%
test['orderDate']
# Out:
# 0        2013-04-01
# 1        2013-04-01
# 2        2013-04-01
# 3        2013-04-01
# 4        2013-04-01
#             ...
# 50073    2013-04-29
# 50074    2013-04-29
# 50075    2013-04-28
# 50076    2013-04-28
# 50077    2013-04-28
# Name: orderDate, Length: 50078, dtype: object

# %%
# Getting Dates to the right format
test['orderDate'] = pd.to_datetime(test['orderDate'], format = '%Y-%m-%d')
test['orderDate']
# Out:
# 0       2013-04-01
# 1       2013-04-01
# 2       2013-04-01
# 3       2013-04-01
# 4       2013-04-01
#            ...
# 50073   2013-04-29
# 50074   2013-04-29
# 50075   2013-04-28
# 50076   2013-04-28
# 50077   2013-04-28
# Name: orderDate, Length: 50078, dtype: datetime64[ns]

# %% [markdown]
# #### deliveryDate & dateOfBirth

# %%
test['deliveryDate'] = pd.to_datetime(test['deliveryDate'], format = '%Y-%m-%d')
test['dateOfBirth'] = pd.to_datetime(test['dateOfBirth'], format = "%Y-%m-%d")

# %% [markdown]
# #### Size

# %%
counting_sizes = test.groupby('size').count().sort_values('orderItemID', ascending = False)
counting_sizes.iloc[0:15,:]
# Out:
#          orderItemID  orderDate  deliveryDate  itemID  color  manufacturerID  \
# size
# L               6823       6823          6400    6823   6823            6823
# XL              6042       6042          5541    6042   6042            6042
# M               5479       5479          5065    5479   5479            5479
# XXL             4615       4615          4247    4615   4615            4615
# 40              3386       3386          3088    3386   3386            3386
# 39              3175       3175          2856    3175   3175            3175
# unsized         2405       2405          2277    2405   2405            2405
# 38              2346       2346          2103    2346   2346            2346
# S               2038       2038          1882    2038   2038            2038
# 41              1993       1993          1848    1993   1993            1993
# 42              1923       1923          1742    1923   1923            1923
# 37              1109       1109           971    1109   1109            1109
# m                815        815           729     815    815             815
# l                740        740           681     740    740             740
# xl               629        629           582     629    629             629
#
#          price  customerID  salutation  dateOfBirth  state  creationDate
# size
# L         6823        6823        6823         6119   6823          6823
# XL        6042        6042        6042         5502   6042          6042
# M         5479        5479        5479         4801   5479          5479
# XXL       4615        4615        4615         4253   4615          4615
# 40        3386        3386        3386         3037   3386          3386
# 39        3175        3175        3175         2830   3175          3175
# unsized   2405        2405        2405         2158   2405          2405
# 38        2346        2346        2346         2045   2346          2346
# S         2038        2038        2038         1815   2038          2038
# 41        1993        1993        1993         1787   1993          1993
# 42        1923        1923        1923         1757   1923          1923
# 37        1109        1109        1109          979   1109          1109
# m          815         815         815          704    815           815
# l          740         740         740          667    740           740
# xl         629         629         629          588    629           629

# %% [markdown]
# #### Color

# %%
counting_color = test.groupby('color').count().sort_values('orderItemID', ascending = False)
counting_color
# Out:
#               orderItemID  orderDate  deliveryDate  itemID  size  \
# color
# black                8346       8346          7672    8346  8346
# green                5226       5226          4782    5226  5226
# blue                 4794       4794          4343    4794  4794
# grey                 4443       4443          4044    4443  4443
# red                  3976       3976          3605    3976  3976
# ...                   ...        ...           ...     ...   ...
# lemon                   2          2             2       2     2
# dark oliv               2          2             1       2     2
# dark navy               1          1             1       1     1
# gold                    1          1             1       1     1
# antique pink            1          1             1       1     1
#
#               manufacturerID  price  customerID  salutation  dateOfBirth  \
# color
# black                   8346   8346        8346        8346         7439
# green                   5226   5226        5226        5226         4639
# blue                    4794   4794        4794        4794         4290
# grey                    4443   4443        4443        4443         3997
# red                     3976   3976        3976        3976         3569
# ...                      ...    ...         ...         ...          ...
# lemon                      2      2           2           2            2
# dark oliv                  2      2           2           2            2
# dark navy                  1      1           1           1            1
# gold                       1      1           1           1            1
# antique pink               1      1           1           1            1
#
#               state  creationDate
# color
# black          8346          8346
# green          5226          5226
# blue           4794          4794
# grey           4443          4443
# red            3976          3976
# ...             ...           ...
# lemon             2             2
# dark oliv         2             2
# dark navy         1             1
# gold              1             1
# antique pink      1             1
#
# [66 rows x 12 columns]

# %%
counting_color = test.groupby('color').count().sort_values('orderItemID', ascending = False)
counting_color.iloc[44:45,:]
# Out:
#        orderItemID  orderDate  deliveryDate  itemID  size  manufacturerID  \
# color
# jade            44         44            41      44    44              44
#
#        price  customerID  salutation  dateOfBirth  state  creationDate
# color
# jade      44          44          44           40     44            44

# %% [markdown]
# ## ManufacturerID 15 has the color brown misspelled. Does that causes a higher return rate?

# %%
test[test['color'] == 'blau'].head()
# Out:
#       orderItemID  orderDate deliveryDate  itemID size color  manufacturerID  \
# 152           153 2013-04-01   2013-04-04    2401    M  blau              20
# 538           539 2013-04-01   2013-04-22    2401    S  blau              20
# 2679         2680 2013-04-02   2013-04-22    2401   XL  blau              20
# 3517         3518 2013-04-03   2013-05-28    2401    L  blau              20
# 5683         5684 2013-04-04   2013-04-10    2401   XL  blau              20
#
#       price  customerID salutation dateOfBirth                   state  \
# 152    59.9       86561        Mrs         NaT                 Hamburg
# 538    59.9       54615        Mrs  1967-04-15                 Bavaria
# 2679   59.9        6182        Mrs  1956-02-09                  Bremen
# 3517   59.9       44746        Mrs  1965-01-26      Baden-Wuerttemberg
# 5683   59.9       50017        Mrs  1969-09-24  North Rhine-Westphalia
#
#      creationDate
# 152    2013-04-01
# 538    2012-10-03
# 2679   2011-02-16
# 3517   2012-09-13
# 5683   2012-09-15

# %% [markdown]
# ## ManufacturerID 3 has the color blue misspelled. Does that causes a higher return rate?

# %% [markdown]
# ## Both of the manufacturer had 37% of return, which is a pretty good rate compared to the rest of the data. Therefore, the misspelling in the collor did not have much effect.

# %%
test['color'] = np.where(test['color'] == 'brwon', 'brown', test['color'])
test['color'] = np.where(test['color'] == 'blau', 'blue', test['color'])

# %% [markdown]
# #### state

# %% [markdown]
# #### creationDate

# %%
# Compute the correlation matrix
corr = test.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
test.shape
# Out:
# (50078, 13)

# %%
test.to_csv('test_dataset.csv', index = False)
